# %%
import sys
import os

sys.path.append(os.path.abspath("../")) 

from data import Tokenizer, Vocabulary, TextLoader, RNNTrainer
from models import LSTM, RNNLM
from utils import get_device
import torch
from torch import nn
import torch.nn.functional as F
import numpy as np

# %%
filename = "../books/time_machine.txt"
data = TextLoader(filename, batch_size=1024, num_steps=32)

# %%
data.raw_text[:20]
# Out:
# 'I\n\n\nThe Time Travell'

# %%
lstm = LSTM(input_size=data.vocab_size, hidden_size=128).to(device=get_device())

model = RNNLM(
    rnn=lstm,
    vocab_size=data.vocab_size,
).to(device=get_device())

model
# Out:
# RNNLM(
#   (rnn): LSTM()
#   (output): Linear(in_features=128, out_features=27, bias=True)
# )

# %%
trainer = RNNTrainer(
    model=model,
    data=data,
    loss_name="cross_entropy",
    optimizer_name="adam",
    device=get_device(),
    lr=0.001,
    optimizer_params={},
    scheduler_name="reduce_on_platue"
)

trainer.train(max_epochs=125)
# Out:
# Epoch [1/125] | LR: 0.001000 | Train Loss: 2.8773 | Val Loss: 2.7589
# Epoch [2/125] | LR: 0.001000 | Train Loss: 2.6385 | Val Loss: 2.4551
# Epoch [3/125] | LR: 0.001000 | Train Loss: 2.3909 | Val Loss: 2.3009
# Epoch [4/125] | LR: 0.001000 | Train Loss: 2.2842 | Val Loss: 2.2317
# Epoch [5/125] | LR: 0.001000 | Train Loss: 2.2217 | Val Loss: 2.1821
# Epoch [6/125] | LR: 0.001000 | Train Loss: 2.1749 | Val Loss: 2.1436
# Epoch [7/125] | LR: 0.001000 | Train Loss: 2.1363 | Val Loss: 2.1113
# Epoch [8/125] | LR: 0.001000 | Train Loss: 2.1032 | Val Loss: 2.0832
# Epoch [9/125] | LR: 0.001000 | Train Loss: 2.0741 | Val Loss: 2.0580
# Epoch [10/125] | LR: 0.001000 | Train Loss: 2.0475 | Val Loss: 2.0340
# Epoch [11/125] | LR: 0.001000 | Train Loss: 2.0221 | Val Loss: 2.0117
# Epoch [12/125] | LR: 0.001000 | Train Loss: 1.9986 | Val Loss: 1.9910
# Epoch [13/125] | LR: 0.001000 | Train Loss: 1.9766 | Val Loss: 1.9720
# Epoch [14/125] | LR: 0.001000 | Train Loss: 1.9561 | Val Loss: 1.9536
# Epoch [15/125] | LR: 0.001000 | Train Loss: 1.9366 | Val Loss: 1.9355
# Epoch [16/125] | LR: 0.001000 | Train Loss: 1.9177 | Val Loss: 1.9176
# Epoch [17/125] | LR: 0.001000 | Train Loss: 1.8994 | Val Loss: 1.9006
# Epoch [18/125] | LR: 0.001000 | Train Loss: 1.8819 | Val Loss: 1.8843
# Epoch [19/125] | LR: 0.001000 | Train Loss: 1.8649 | Val Loss: 1.8685
# Epoch [20/125] | LR: 0.001000 | Train Loss: 1.8483 | Val Loss: 1.8532
# Epoch [21/125] | LR: 0.001000 | Train Loss: 1.8322 | Val Loss: 1.8387
# Epoch [22/125] | LR: 0.001000 | Train Loss: 1.8165 | Val Loss: 1.8249
# Epoch [23/125] | LR: 0.001000 | Train Loss: 1.8012 | Val Loss: 1.8121
# Epoch [24/125] | LR: 0.001000 | Train Loss: 1.7864 | Val Loss: 1.7999
# Epoch [25/125] | LR: 0.001000 | Train Loss: 1.7722 | Val Loss: 1.7884
# Epoch [26/125] | LR: 0.001000 | Train Loss: 1.7586 | Val Loss: 1.7774
# Epoch [27/125] | LR: 0.001000 | Train Loss: 1.7455 | Val Loss: 1.7671
# Epoch [28/125] | LR: 0.001000 | Train Loss: 1.7325 | Val Loss: 1.7566
# Epoch [29/125] | LR: 0.001000 | Train Loss: 1.7196 | Val Loss: 1.7466
# Epoch [30/125] | LR: 0.001000 | Train Loss: 1.7067 | Val Loss: 1.7368
# Epoch [31/125] | LR: 0.001000 | Train Loss: 1.6940 | Val Loss: 1.7270
# Epoch [32/125] | LR: 0.001000 | Train Loss: 1.6815 | Val Loss: 1.7175
# Epoch [33/125] | LR: 0.001000 | Train Loss: 1.6691 | Val Loss: 1.7079
# Epoch [34/125] | LR: 0.001000 | Train Loss: 1.6570 | Val Loss: 1.6988
# Epoch [35/125] | LR: 0.001000 | Train Loss: 1.6454 | Val Loss: 1.6900
# Epoch [36/125] | LR: 0.001000 | Train Loss: 1.6339 | Val Loss: 1.6813
# Epoch [37/125] | LR: 0.001000 | Train Loss: 1.6229 | Val Loss: 1.6729
# Epoch [38/125] | LR: 0.001000 | Train Loss: 1.6120 | Val Loss: 1.6648
# Epoch [39/125] | LR: 0.001000 | Train Loss: 1.6017 | Val Loss: 1.6571
# Epoch [40/125] | LR: 0.001000 | Train Loss: 1.5916 | Val Loss: 1.6498
# Epoch [41/125] | LR: 0.001000 | Train Loss: 1.5818 | Val Loss: 1.6428
# Epoch [42/125] | LR: 0.001000 | Train Loss: 1.5725 | Val Loss: 1.6361
# Epoch [43/125] | LR: 0.001000 | Train Loss: 1.5633 | Val Loss: 1.6298
# Epoch [44/125] | LR: 0.001000 | Train Loss: 1.5545 | Val Loss: 1.6235
# Epoch [45/125] | LR: 0.001000 | Train Loss: 1.5459 | Val Loss: 1.6175
# Epoch [46/125] | LR: 0.001000 | Train Loss: 1.5376 | Val Loss: 1.6118
# Epoch [47/125] | LR: 0.001000 | Train Loss: 1.5296 | Val Loss: 1.6064
# Epoch [48/125] | LR: 0.001000 | Train Loss: 1.5218 | Val Loss: 1.6012
# Epoch [49/125] | LR: 0.001000 | Train Loss: 1.5142 | Val Loss: 1.5962
# Epoch [50/125] | LR: 0.001000 | Train Loss: 1.5068 | Val Loss: 1.5914
# Epoch [51/125] | LR: 0.001000 | Train Loss: 1.4995 | Val Loss: 1.5869
# Epoch [52/125] | LR: 0.001000 | Train Loss: 1.4925 | Val Loss: 1.5825
# Epoch [53/125] | LR: 0.001000 | Train Loss: 1.4855 | Val Loss: 1.5784
# Epoch [54/125] | LR: 0.001000 | Train Loss: 1.4788 | Val Loss: 1.5744
# Epoch [55/125] | LR: 0.001000 | Train Loss: 1.4723 | Val Loss: 1.5707
# Epoch [56/125] | LR: 0.001000 | Train Loss: 1.4659 | Val Loss: 1.5671
# Epoch [57/125] | LR: 0.001000 | Train Loss: 1.4596 | Val Loss: 1.5638
# Epoch [58/125] | LR: 0.001000 | Train Loss: 1.4535 | Val Loss: 1.5606
# Epoch [59/125] | LR: 0.001000 | Train Loss: 1.4476 | Val Loss: 1.5577
# Epoch [60/125] | LR: 0.001000 | Train Loss: 1.4418 | Val Loss: 1.5548
# Epoch [61/125] | LR: 0.001000 | Train Loss: 1.4361 | Val Loss: 1.5521
# Epoch [62/125] | LR: 0.001000 | Train Loss: 1.4306 | Val Loss: 1.5495
# Epoch [63/125] | LR: 0.001000 | Train Loss: 1.4252 | Val Loss: 1.5471
# Epoch [64/125] | LR: 0.001000 | Train Loss: 1.4199 | Val Loss: 1.5449
# Epoch [65/125] | LR: 0.001000 | Train Loss: 1.4147 | Val Loss: 1.5429
# Epoch [66/125] | LR: 0.001000 | Train Loss: 1.4097 | Val Loss: 1.5409
# Epoch [67/125] | LR: 0.001000 | Train Loss: 1.4049 | Val Loss: 1.5390
# Epoch [68/125] | LR: 0.001000 | Train Loss: 1.4001 | Val Loss: 1.5373
# Epoch [69/125] | LR: 0.001000 | Train Loss: 1.3954 | Val Loss: 1.5357
# Epoch [70/125] | LR: 0.001000 | Train Loss: 1.3909 | Val Loss: 1.5341
# Epoch [71/125] | LR: 0.001000 | Train Loss: 1.3864 | Val Loss: 1.5327
# Epoch [72/125] | LR: 0.001000 | Train Loss: 1.3821 | Val Loss: 1.5313
# Epoch [73/125] | LR: 0.001000 | Train Loss: 1.3777 | Val Loss: 1.5302
# Epoch [74/125] | LR: 0.001000 | Train Loss: 1.3736 | Val Loss: 1.5289
# Epoch [75/125] | LR: 0.001000 | Train Loss: 1.3695 | Val Loss: 1.5278
# Epoch [76/125] | LR: 0.001000 | Train Loss: 1.3655 | Val Loss: 1.5268
# Epoch [77/125] | LR: 0.001000 | Train Loss: 1.3615 | Val Loss: 1.5259
# Epoch [78/125] | LR: 0.001000 | Train Loss: 1.3577 | Val Loss: 1.5250
# Epoch [79/125] | LR: 0.001000 | Train Loss: 1.3539 | Val Loss: 1.5242
# Epoch [80/125] | LR: 0.001000 | Train Loss: 1.3501 | Val Loss: 1.5235
# Epoch [81/125] | LR: 0.001000 | Train Loss: 1.3465 | Val Loss: 1.5229
# Epoch [82/125] | LR: 0.001000 | Train Loss: 1.3429 | Val Loss: 1.5223
# Epoch [83/125] | LR: 0.001000 | Train Loss: 1.3394 | Val Loss: 1.5217
# Epoch [84/125] | LR: 0.001000 | Train Loss: 1.3360 | Val Loss: 1.5213
# Epoch [85/125] | LR: 0.001000 | Train Loss: 1.3326 | Val Loss: 1.5208
# Epoch [86/125] | LR: 0.001000 | Train Loss: 1.3292 | Val Loss: 1.5206
# Epoch [87/125] | LR: 0.001000 | Train Loss: 1.3259 | Val Loss: 1.5203
# Epoch [88/125] | LR: 0.001000 | Train Loss: 1.3228 | Val Loss: 1.5201
# Epoch [89/125] | LR: 0.001000 | Train Loss: 1.3195 | Val Loss: 1.5200
# Epoch [90/125] | LR: 0.001000 | Train Loss: 1.3165 | Val Loss: 1.5199
# Epoch [91/125] | LR: 0.001000 | Train Loss: 1.3134 | Val Loss: 1.5199
# Epoch [92/125] | LR: 0.001000 | Train Loss: 1.3103 | Val Loss: 1.5200
# Epoch [93/125] | LR: 0.001000 | Train Loss: 1.3074 | Val Loss: 1.5201
# Epoch [94/125] | LR: 0.001000 | Train Loss: 1.3045 | Val Loss: 1.5203
# Epoch [95/125] | LR: 0.001000 | Train Loss: 1.3016 | Val Loss: 1.5205
# Epoch [96/125] | LR: 0.001000 | Train Loss: 1.2987 | Val Loss: 1.5209
# Epoch [97/125] | LR: 0.001000 | Train Loss: 1.2960 | Val Loss: 1.5211
# Epoch [98/125] | LR: 0.001000 | Train Loss: 1.2933 | Val Loss: 1.5216
# Epoch [99/125] | LR: 0.001000 | Train Loss: 1.2905 | Val Loss: 1.5221
# Epoch [100/125] | LR: 0.001000 | Train Loss: 1.2879 | Val Loss: 1.5226
# Epoch [101/125] | LR: 0.001000 | Train Loss: 1.2853 | Val Loss: 1.5232
# Epoch [102/125] | LR: 0.001000 | Train Loss: 1.2827 | Val Loss: 1.5238
# Epoch [103/125] | LR: 0.001000 | Train Loss: 1.2802 | Val Loss: 1.5244
# Epoch [104/125] | LR: 0.001000 | Train Loss: 1.2777 | Val Loss: 1.5251
# Epoch [105/125] | LR: 0.001000 | Train Loss: 1.2752 | Val Loss: 1.5259
# Epoch [106/125] | LR: 0.001000 | Train Loss: 1.2728 | Val Loss: 1.5267
# Epoch [107/125] | LR: 0.001000 | Train Loss: 1.2704 | Val Loss: 1.5275
# Epoch [108/125] | LR: 0.001000 | Train Loss: 1.2680 | Val Loss: 1.5285
# Epoch [109/125] | LR: 0.001000 | Train Loss: 1.2658 | Val Loss: 1.5293
# Epoch [110/125] | LR: 0.001000 | Train Loss: 1.2635 | Val Loss: 1.5303
# Epoch [111/125] | LR: 0.001000 | Train Loss: 1.2612 | Val Loss: 1.5313
# Epoch [112/125] | LR: 0.001000 | Train Loss: 1.2589 | Val Loss: 1.5323
# Epoch [113/125] | LR: 0.001000 | Train Loss: 1.2568 | Val Loss: 1.5332
# Epoch [114/125] | LR: 0.001000 | Train Loss: 1.2545 | Val Loss: 1.5344
# Epoch [115/125] | LR: 0.001000 | Train Loss: 1.2524 | Val Loss: 1.5355
# Epoch [116/125] | LR: 0.001000 | Train Loss: 1.2503 | Val Loss: 1.5364
# Epoch [117/125] | LR: 0.001000 | Train Loss: 1.2482 | Val Loss: 1.5375
# Epoch [118/125] | LR: 0.001000 | Train Loss: 1.2461 | Val Loss: 1.5386
# Epoch [119/125] | LR: 0.001000 | Train Loss: 1.2441 | Val Loss: 1.5398
# Epoch [120/125] | LR: 0.001000 | Train Loss: 1.2420 | Val Loss: 1.5410
# Epoch [121/125] | LR: 0.001000 | Train Loss: 1.2399 | Val Loss: 1.5421
# Epoch [122/125] | LR: 0.001000 | Train Loss: 1.2379 | Val Loss: 1.5433
# Epoch [123/125] | LR: 0.001000 | Train Loss: 1.2360 | Val Loss: 1.5444
# Epoch [124/125] | LR: 0.001000 | Train Loss: 1.2341 | Val Loss: 1.5455
# Epoch [125/125] | LR: 0.001000 | Train Loss: 1.2321 | Val Loss: 1.5468
